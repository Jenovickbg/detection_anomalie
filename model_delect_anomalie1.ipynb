# %% [markdown]
# # Détection d'Anomalies avec Machine Learning(IA)

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import numpy as np
X, y = make_blobs(n_samples=50, centers=1, cluster_std=1.0, random_state=42)
X[-1, :] = np.array([5, 5])  
plt.scatter(X[:, 0], X[:, 1])  
plt.title(" données générées")
plt.show()

# %%
from sklearn.ensemble import IsolationForest

# %%
model=IsolationForest(contamination=0.01)
model.fit(X)
# Out:
# IsolationForest(contamination=0.01)

# %%
plt.scatter(X[:, 0], X[:, 1],c=model.predict(X))

# %%
from sklearn.datasets import load_digits

# %%
digits =load_digits()

# %%
images=digits.images

# %%
X=digits.data
y=digits.target
print(X.shape)
# Out:
# (1797, 64)

# %%
plt.imshow(images[10])

# %%
 model=IsolationForest(random_state=0,contamination=0.02)

# %%
model.fit(X)
# Out:
# IsolationForest(contamination=0.02, random_state=0)

# %%
out=model.predict(X) == -1

# %%
out
# Out:
# array([False, False, False, ..., False, False, False])

# %%
plt.imshow(images[out][11])
plt.title(y[out][11])
# Out:
# Text(0.5, 1.0, '4')

# %%
bien=model.predict(X) == 1

# %%
bien
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
plt.imshow(images[bien][181])
plt.title(y[bien][181])
# Out:
# Text(0.5, 1.0, '8')
